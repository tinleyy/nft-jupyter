# %%
import matplotlib.pyplot as plt
from samila import GenerativeImage, Projection
import random
import math

def f1(x, y):
    result = random.uniform(-1,1) * x**2  - math.sin(y**2) + abs(y-x)
    return result

def f2(x, y):
    result = random.uniform(-1,1) * y**3 - math.cos(x**2) + 2*x
    return result

#Project
g = GenerativeImage(f1, f2)
g.generate()

# RECTILINEAR, POLAR, AITOFF, HAMMER, LAMBERT, MOLLWEIDE, RANDOM
g.plot(color="red", bgcolor="black", projection=Projection.POLAR)
g.seed
plt.show()

# %%
g.nft_storage(api_key="")
# Out:
# {'status': True,
#  'message': 'https://ipfs.io/ipfs/bafybeibo3l4ytax3o4d3necvxasb5uecbr5hurhiz6dig665lfdvelzoye'}

# %%
g.save_image(file_adr="test.png")
# Out:
# {'status': True, 'message': '/Users/tinley/nft-jupyter/test.png'}
